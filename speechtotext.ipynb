# %% [markdown]
# <a href="https://colab.research.google.com/github/RiyaDwivedi747/AdvAItraining/blob/main/speechtotext.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#create text audio using whisper model
